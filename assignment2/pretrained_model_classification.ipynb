# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/My Drive/imagenet')

# %%
# !pwd
# Out:
# /content/drive/My Drive/imagenet

# %%
import torchvision

testset = torchvision.datasets.ImageNet(root="./", split='val')

# %%
from torchvision.models import alexnet

model = alexnet(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/alexnet-owt-4df8aa71.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-4df8aa71.pth
# HBox(children=(FloatProgress(value=0.0, max=244418560.0), HTML(value='')))

# %%
import torch
import torchvision
import torch.utils.data as data
import torchvision.transforms as transforms


if __name__ == "__main__":
    device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
    normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std=[0.229, 0.224, 0.225])

    transform = transforms.Compose(
        [transforms.Resize(256),
         transforms.CenterCrop(224),
         transforms.ToTensor(),
         normalize,
         ])

    test_set = torchvision.datasets.ImageNet(root="./", transform=transform, split='val')
    test_loader = data.DataLoader(test_set, batch_size=128, shuffle=True, num_workers=2)

    model = torchvision.models.alexnet(pretrained=True).to(device)
    model.eval()

    correct_top1 = 0
    total = 0

    with torch.no_grad():
        for idx, (images, labels) in enumerate(test_loader):

            images = images.to(device)      # [100, 3, 224, 224]
            labels = labels.to(device)      # [100]
            outputs = model(images)

            # ------------------------------------------------------------------------------
            # rank 1
            _, pred = torch.max(outputs, 1)
            total += labels.size(0)
            correct_top1 += (pred == labels).sum().item()

            # ------------------------------------------------------------------------------

            print("step : {} / {}".format(idx + 1, len(test_set)/int(labels.size(0))))
            print("top-1 percentage :  {0:0.2f}%".format(correct_top1 / total * 100))
    print("---------------------------------------------------------------")     
    print("AlexNet") 
    print("top-1 percentage :  {0:0.2f}%".format(correct_top1 / total * 100))
# Out:
# step : 377 / 390.625
# top-1 percentage :  56.45%
# step : 378 / 390.625
# top-1 percentage :  56.46%
# step : 379 / 390.625
# top-1 percentage :  56.47%
# step : 380 / 390.625
# top-1 percentage :  56.47%
# step : 381 / 390.625
# top-1 percentage :  56.48%
# step : 382 / 390.625
# top-1 percentage :  56.50%
# step : 383 / 390.625
# top-1 percentage :  56.50%
# step : 384 / 390.625
# top-1 percentage :  56.49%
# step : 385 / 390.625
# top-1 percentage :  56.50%
# step : 386 / 390.625
# top-1 percentage :  56.50%
# step : 387 / 390.625
# top-1 percentage :  56.50%
# step : 388 / 390.625
# top-1 percentage :  56.50%
# step : 389 / 390.625
# top-1 percentage :  56.50%
# step : 390 / 390.625
# top-1 percentage :  56.50%
# step : 391 / 625.0
# top-1 percentage :  56.52%
# ---------------------------------------------------------------
# AlexNet
# top-1 percentage :  56.52%

# %%
# !pwd
# Out:
# /content/drive/My Drive/imagenet

# %%
from torchvision.models import vgg16
model = vgg16(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# HBox(children=(FloatProgress(value=0.0, max=553433881.0), HTML(value='')))

# %%
import torch
import torchvision
import torch.utils.data as data
import torchvision.transforms as transforms


if __name__ == "__main__":
    device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
    normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std=[0.229, 0.224, 0.225])

    transform = transforms.Compose(
        [transforms.Resize(256),
         transforms.CenterCrop(224),
         transforms.ToTensor(),
         normalize,
         ])

    test_set = torchvision.datasets.ImageNet(root="./", transform=transform, split='val')
    test_loader = data.DataLoader(test_set, batch_size=128, shuffle=True, num_workers=2)

    model = torchvision.models.vgg16(pretrained=True).to(device)
    model.eval()

    correct_top1 = 0
    total = 0

    with torch.no_grad():
        for idx, (images, labels) in enumerate(test_loader):

            images = images.to(device)      # [100, 3, 224, 224]
            labels = labels.to(device)      # [100]
            outputs = model(images)

            # ------------------------------------------------------------------------------
            # rank 1
            _, pred = torch.max(outputs, 1)
            total += labels.size(0)
            correct_top1 += (pred == labels).sum().item()

            # ------------------------------------------------------------------------------

            print("step : {} / {}".format(idx + 1, len(test_set)/int(labels.size(0))))
            print("top-1 percentage :  {0:0.2f}%".format(correct_top1 / total * 100))
    print("---------------------------------------------------------------")         
    print("top-1 percentage :  {0:0.2f}%".format(correct_top1 / total * 100))
# Out:
# step : 1 / 390.625
# top-1 percentage :  77.34%
# step : 2 / 390.625
# top-1 percentage :  75.00%
# step : 3 / 390.625
# top-1 percentage :  73.70%
# step : 4 / 390.625
# top-1 percentage :  73.05%
# step : 5 / 390.625
# top-1 percentage :  72.34%
# step : 6 / 390.625
# top-1 percentage :  72.66%
# step : 7 / 390.625
# top-1 percentage :  73.55%
# step : 8 / 390.625
# top-1 percentage :  73.83%
# step : 9 / 390.625
# top-1 percentage :  73.96%
# step : 10 / 390.625
# top-1 percentage :  73.98%
# step : 11 / 390.625
# top-1 percentage :  73.93%
# step : 12 / 390.625
# top-1 percentage :  73.50%
# step : 13 / 390.625
# top-1 percentage :  73.80%
# step : 14 / 390.625
# top-1 percentage :  73.83%
# step : 15 / 390.625
# top-1 percentage :  73.44%
# step : 16 / 390.625
# top-1 percentage :  73.24%
# step : 17 / 390.625
# top-1 percentage :  73.12%
# step : 18 / 390.625
# top-1 percentage :  73.00%
# step : 19 / 390.625
# top-1 percentage :  72.62%
# step : 20 / 390.625
# top-1 percentage :  72.07%
# step : 21 / 390.625
# top-1 percentage :  71.84%
# step : 22 / 390.625
# top-1 percentage :  71.66%
# step : 23 / 390.625
# top-1 percentage :  71.71%
# step : 24 / 390.625
# top-1 percentage :  71.68%
# step : 25 / 390.625
# top-1 percentage :  71.25%
# step : 26 / 390.625
# top-1 percentage :  71.27%
# step : 27 / 390.625
# top-1 percentage :  71.27%
# step : 28 / 390.625
# top-1 percentage :  71.37%
# step : 29 / 390.625
# top-1 percentage :  71.28%
# step : 30 / 390.625
# top-1 percentage :  71.33%
# step : 31 / 390.625
# top-1 percentage :  71.09%
# step : 32 / 390.625
# top-1 percentage :  71.17%
# step : 33 / 390.625
# top-1 percentage :  71.00%
# step : 34 / 390.625
# top-1 percentage :  71.05%
# step : 35 / 390.625
# top-1 percentage :  71.03%
# step : 36 / 390.625
# top-1 percentage :  71.03%
# step : 37 / 390.625
# top-1 percentage :  71.03%
# step : 38 / 390.625
# top-1 percentage :  70.89%
# step : 39 / 390.625
# top-1 percentage :  70.95%
# step : 40 / 390.625
# top-1 percentage :  71.11%
# step : 41 / 390.625
# top-1 percentage :  71.21%
# step : 42 / 390.625
# top-1 percentage :  71.00%
# step : 43 / 390.625
# top-1 percentage :  70.84%
# step : 44 / 390.625
# top-1 percentage :  70.86%
# step : 45 / 390.625
# top-1 percentage :  70.80%
# step : 46 / 390.625
# top-1 percentage :  70.87%
# step : 47 / 390.625
# top-1 percentage :  70.93%
# step : 48 / 390.625
# top-1 percentage :  70.93%
# step : 49 / 390.625
# top-1 percentage :  70.82%
# step : 50 / 390.625
# top-1 percentage :  70.92%
# step : 51 / 390.625
# top-1 percentage :  70.99%
# step : 52 / 390.625
# top-1 percentage :  70.88%
# step : 53 / 390.625
# top-1 percentage :  70.83%
# step : 54 / 390.625
# top-1 percentage :  70.86%
# step : 55 / 390.625
# top-1 percentage :  70.80%
# step : 56 / 390.625
# top-1 percentage :  70.76%
# step : 57 / 390.625
# top-1 percentage :  70.79%
# step : 58 / 390.625
# top-1 percentage :  70.84%
# step : 59 / 390.625
# top-1 percentage :  70.95%
# step : 60 / 390.625
# top-1 percentage :  71.05%
# step : 61 / 390.625
# top-1 percentage :  71.13%
# step : 62 / 390.625
# top-1 percentage :  71.16%
# step : 63 / 390.625
# top-1 percentage :  71.24%
# step : 64 / 390.625
# top-1 percentage :  71.25%
# step : 65 / 390.625
# top-1 percentage :  71.26%
# step : 66 / 390.625
# top-1 percentage :  71.25%
# step : 67 / 390.625
# top-1 percentage :  71.33%
# step : 68 / 390.625
# top-1 percentage :  71.29%
# step : 69 / 390.625
# top-1 percentage :  71.32%
# step : 70 / 390.625
# top-1 percentage :  71.16%
# step : 71 / 390.625
# top-1 percentage :  71.17%
# step : 72 / 390.625
# top-1 percentage :  71.10%
# step : 73 / 390.625
# top-1 percentage :  71.13%
# step : 74 / 390.625
# top-1 percentage :  71.16%
# step : 75 / 390.625
# top-1 percentage :  71.26%
# step : 76 / 390.625
# top-1 percentage :  71.27%
# step : 77 / 390.625
# top-1 percentage :  71.31%
# step : 78 / 390.625
# top-1 percentage :  71.30%
# step : 79 / 390.625
# top-1 percentage :  71.31%
# step : 80 / 390.625
# top-1 percentage :  71.34%
# step : 81 / 390.625
# top-1 percentage :  71.37%
# step : 82 / 390.625
# top-1 percentage :  71.42%
# step : 83 / 390.625
# top-1 percentage :  71.36%
# step : 84 / 390.625
# top-1 percentage :  71.32%
# step : 85 / 390.625
# top-1 percentage :  71.31%
# step : 86 / 390.625
# top-1 percentage :  71.29%
# step : 87 / 390.625
# top-1 percentage :  71.34%
# step : 88 / 390.625
# top-1 percentage :  71.32%
# step : 89 / 390.625
# top-1 percentage :  71.33%
# step : 90 / 390.625
# top-1 percentage :  71.35%
# step : 91 / 390.625
# top-1 percentage :  71.37%
# step : 92 / 390.625
# top-1 percentage :  71.33%
# step : 93 / 390.625
# top-1 percentage :  71.38%
# step : 94 / 390.625
# top-1 percentage :  71.35%
# step : 95 / 390.625
# top-1 percentage :  71.36%
# step : 96 / 390.625
# top-1 percentage :  71.47%
# step : 97 / 390.625
# top-1 percentage :  71.38%
# step : 98 / 390.625
# top-1 percentage :  71.36%
# step : 99 / 390.625
# top-1 percentage :  71.41%
# step : 100 / 390.625
# top-1 percentage :  71.38%
# step : 101 / 390.625
# top-1 percentage :  71.36%
# step : 102 / 390.625
# top-1 percentage :  71.32%
# step : 103 / 390.625
# top-1 percentage :  71.33%
# step : 104 / 390.625
# top-1 percentage :  71.35%
# step : 105 / 390.625
# top-1 percentage :  71.38%
# step : 106 / 390.625
# top-1 percentage :  71.42%
# step : 107 / 390.625
# top-1 percentage :  71.44%
# step : 108 / 390.625
# top-1 percentage :  71.43%
# step : 109 / 390.625
# top-1 percentage :  71.44%
# step : 110 / 390.625
# top-1 percentage :  71.43%
# step : 111 / 390.625
# top-1 percentage :  71.45%
# step : 112 / 390.625
# top-1 percentage :  71.48%
# step : 113 / 390.625
# top-1 percentage :  71.51%
# step : 114 / 390.625
# top-1 percentage :  71.50%
# step : 115 / 390.625
# top-1 percentage :  71.56%
# step : 116 / 390.625
# top-1 percentage :  71.50%
# step : 117 / 390.625
# top-1 percentage :  71.47%
# step : 118 / 390.625
# top-1 percentage :  71.44%
# step : 119 / 390.625
# top-1 percentage :  71.42%
# step : 120 / 390.625
# top-1 percentage :  71.41%
# step : 121 / 390.625
# top-1 percentage :  71.42%
# step : 122 / 390.625
# top-1 percentage :  71.41%
# step : 123 / 390.625
# top-1 percentage :  71.39%
# step : 124 / 390.625
# top-1 percentage :  71.41%
# step : 125 / 390.625
# top-1 percentage :  71.41%
# step : 126 / 390.625
# top-1 percentage :  71.45%
# step : 127 / 390.625
# top-1 percentage :  71.45%
# step : 128 / 390.625
# top-1 percentage :  71.49%
# step : 129 / 390.625
# top-1 percentage :  71.51%
# step : 130 / 390.625
# top-1 percentage :  71.53%
# step : 131 / 390.625
# top-1 percentage :  71.49%
# step : 132 / 390.625
# top-1 percentage :  71.48%
# step : 133 / 390.625
# top-1 percentage :  71.50%
# step : 134 / 390.625
# top-1 percentage :  71.47%
# step : 135 / 390.625
# top-1 percentage :  71.50%
# step : 136 / 390.625
# top-1 percentage :  71.51%
# step : 137 / 390.625
# top-1 percentage :  71.53%
# step : 138 / 390.625
# top-1 percentage :  71.52%
# step : 139 / 390.625
# top-1 percentage :  71.49%
# step : 140 / 390.625
# top-1 percentage :  71.48%
# step : 141 / 390.625
# top-1 percentage :  71.43%
# step : 142 / 390.625
# top-1 percentage :  71.42%
# step : 143 / 390.625
# top-1 percentage :  71.42%
# step : 144 / 390.625
# top-1 percentage :  71.40%
# step : 145 / 390.625
# top-1 percentage :  71.41%
# step : 146 / 390.625
# top-1 percentage :  71.40%
# step : 147 / 390.625
# top-1 percentage :  71.38%
# step : 148 / 390.625
# top-1 percentage :  71.39%
# step : 149 / 390.625
# top-1 percentage :  71.42%
# step : 150 / 390.625
# top-1 percentage :  71.42%
# step : 151 / 390.625
# top-1 percentage :  71.37%
# step : 152 / 390.625
# top-1 percentage :  71.38%
# step : 153 / 390.625
# top-1 percentage :  71.38%
# step : 154 / 390.625
# top-1 percentage :  71.40%
# step : 155 / 390.625
# top-1 percentage :  71.42%
# step : 156 / 390.625
# top-1 percentage :  71.45%
# step : 157 / 390.625
# top-1 percentage :  71.45%
# step : 158 / 390.625
# top-1 percentage :  71.47%
# step : 159 / 390.625
# top-1 percentage :  71.45%
# step : 160 / 390.625
# top-1 percentage :  71.44%
# step : 161 / 390.625
# top-1 percentage :  71.44%
# step : 162 / 390.625
# top-1 percentage :  71.42%
# step : 163 / 390.625
# top-1 percentage :  71.39%
# step : 164 / 390.625
# top-1 percentage :  71.38%
# step : 165 / 390.625
# top-1 percentage :  71.35%
# step : 166 / 390.625
# top-1 percentage :  71.38%
# step : 167 / 390.625
# top-1 percentage :  71.35%
# step : 168 / 390.625
# top-1 percentage :  71.37%
# step : 169 / 390.625
# top-1 percentage :  71.41%
# step : 170 / 390.625
# top-1 percentage :  71.43%
# step : 171 / 390.625
# top-1 percentage :  71.44%
# step : 172 / 390.625
# top-1 percentage :  71.44%
# step : 173 / 390.625
# top-1 percentage :  71.41%
# step : 174 / 390.625
# top-1 percentage :  71.43%
# step : 175 / 390.625
# top-1 percentage :  71.44%
# step : 176 / 390.625
# top-1 percentage :  71.45%
# step : 177 / 390.625
# top-1 percentage :  71.49%
# step : 178 / 390.625
# top-1 percentage :  71.47%
# step : 179 / 390.625
# top-1 percentage :  71.47%
# step : 180 / 390.625
# top-1 percentage :  71.47%
# step : 181 / 390.625
# top-1 percentage :  71.48%
# step : 182 / 390.625
# top-1 percentage :  71.44%
# step : 183 / 390.625
# top-1 percentage :  71.43%
# step : 184 / 390.625
# top-1 percentage :  71.44%
# step : 185 / 390.625
# top-1 percentage :  71.43%
# step : 186 / 390.625
# top-1 percentage :  71.41%
# step : 187 / 390.625
# top-1 percentage :  71.42%
# step : 188 / 390.625
# top-1 percentage :  71.44%
# step : 189 / 390.625
# top-1 percentage :  71.45%
# step : 190 / 390.625
# top-1 percentage :  71.47%
# step : 191 / 390.625
# top-1 percentage :  71.47%
# step : 192 / 390.625
# top-1 percentage :  71.49%
# step : 193 / 390.625
# top-1 percentage :  71.47%
# step : 194 / 390.625
# top-1 percentage :  71.48%
# step : 195 / 390.625
# top-1 percentage :  71.45%
# step : 196 / 390.625
# top-1 percentage :  71.44%
# step : 197 / 390.625
# top-1 percentage :  71.45%
# step : 198 / 390.625
# top-1 percentage :  71.46%
# step : 199 / 390.625
# top-1 percentage :  71.45%
# step : 200 / 390.625
# top-1 percentage :  71.48%
# step : 201 / 390.625
# top-1 percentage :  71.50%
# step : 202 / 390.625
# top-1 percentage :  71.48%
# step : 203 / 390.625
# top-1 percentage :  71.49%
# step : 204 / 390.625
# top-1 percentage :  71.50%
# step : 205 / 390.625
# top-1 percentage :  71.52%
# step : 206 / 390.625
# top-1 percentage :  71.55%
# step : 207 / 390.625
# top-1 percentage :  71.53%
# step : 208 / 390.625
# top-1 percentage :  71.51%
# step : 209 / 390.625
# top-1 percentage :  71.53%
# step : 210 / 390.625
# top-1 percentage :  71.51%
# step : 211 / 390.625
# top-1 percentage :  71.48%
# step : 212 / 390.625
# top-1 percentage :  71.46%
# step : 213 / 390.625
# top-1 percentage :  71.46%
# step : 214 / 390.625
# top-1 percentage :  71.42%
# step : 215 / 390.625
# top-1 percentage :  71.41%
# step : 216 / 390.625
# top-1 percentage :  71.40%
# step : 217 / 390.625
# top-1 percentage :  71.41%
# step : 218 / 390.625
# top-1 percentage :  71.42%
# step : 219 / 390.625
# top-1 percentage :  71.41%
# step : 220 / 390.625
# top-1 percentage :  71.42%
# step : 221 / 390.625
# top-1 percentage :  71.45%
# step : 222 / 390.625
# top-1 percentage :  71.42%
# step : 223 / 390.625
# top-1 percentage :  71.44%
# step : 224 / 390.625
# top-1 percentage :  71.43%
# step : 225 / 390.625
# top-1 percentage :  71.42%
# step : 226 / 390.625
# top-1 percentage :  71.44%
# step : 227 / 390.625
# top-1 percentage :  71.45%
# step : 228 / 390.625
# top-1 percentage :  71.45%
# step : 229 / 390.625
# top-1 percentage :  71.48%
# step : 230 / 390.625
# top-1 percentage :  71.46%
# step : 231 / 390.625
# top-1 percentage :  71.48%
# step : 232 / 390.625
# top-1 percentage :  71.46%
# step : 233 / 390.625
# top-1 percentage :  71.46%
# step : 234 / 390.625
# top-1 percentage :  71.48%
# step : 235 / 390.625
# top-1 percentage :  71.51%
# step : 236 / 390.625
# top-1 percentage :  71.50%
# step : 237 / 390.625
# top-1 percentage :  71.52%
# step : 238 / 390.625
# top-1 percentage :  71.52%
# step : 239 / 390.625
# top-1 percentage :  71.53%
# step : 240 / 390.625
# top-1 percentage :  71.54%
# step : 241 / 390.625
# top-1 percentage :  71.54%
# step : 242 / 390.625
# top-1 percentage :  71.54%
# step : 243 / 390.625
# top-1 percentage :  71.52%
# step : 244 / 390.625
# top-1 percentage :  71.54%
# step : 245 / 390.625
# top-1 percentage :  71.54%
# step : 246 / 390.625
# top-1 percentage :  71.53%
# step : 247 / 390.625
# top-1 percentage :  71.53%
# step : 248 / 390.625
# top-1 percentage :  71.56%
# step : 249 / 390.625
# top-1 percentage :  71.58%
# step : 250 / 390.625
# top-1 percentage :  71.58%
# step : 251 / 390.625
# top-1 percentage :  71.61%
# step : 252 / 390.625
# top-1 percentage :  71.61%
# step : 253 / 390.625
# top-1 percentage :  71.60%
# step : 254 / 390.625
# top-1 percentage :  71.60%
# step : 255 / 390.625
# top-1 percentage :  71.61%
# step : 256 / 390.625
# top-1 percentage :  71.60%
# step : 257 / 390.625
# top-1 percentage :  71.60%
# step : 258 / 390.625
# top-1 percentage :  71.61%
# step : 259 / 390.625
# top-1 percentage :  71.63%
# step : 260 / 390.625
# top-1 percentage :  71.63%
# step : 261 / 390.625
# top-1 percentage :  71.61%
# step : 262 / 390.625
# top-1 percentage :  71.60%
# step : 263 / 390.625
# top-1 percentage :  71.60%
# step : 264 / 390.625
# top-1 percentage :  71.60%
# step : 265 / 390.625
# top-1 percentage :  71.60%
# step : 266 / 390.625
# top-1 percentage :  71.62%
# step : 267 / 390.625
# top-1 percentage :  71.62%
# step : 268 / 390.625
# top-1 percentage :  71.61%
# step : 269 / 390.625
# top-1 percentage :  71.64%
# step : 270 / 390.625
# top-1 percentage :  71.63%
# step : 271 / 390.625
# top-1 percentage :  71.63%
# step : 272 / 390.625
# top-1 percentage :  71.64%
# step : 273 / 390.625
# top-1 percentage :  71.65%
# step : 274 / 390.625
# top-1 percentage :  71.66%
# step : 275 / 390.625
# top-1 percentage :  71.66%
# step : 276 / 390.625
# top-1 percentage :  71.65%
# step : 277 / 390.625
# top-1 percentage :  71.64%
# step : 278 / 390.625
# top-1 percentage :  71.64%
# step : 279 / 390.625
# top-1 percentage :  71.65%
# step : 280 / 390.625
# top-1 percentage :  71.64%
# step : 281 / 390.625
# top-1 percentage :  71.64%
# step : 282 / 390.625
# top-1 percentage :  71.64%
# step : 283 / 390.625
# top-1 percentage :  71.63%
# step : 284 / 390.625
# top-1 percentage :  71.64%
# step : 285 / 390.625
# top-1 percentage :  71.66%
# step : 286 / 390.625
# top-1 percentage :  71.63%
# step : 287 / 390.625
# top-1 percentage :  71.61%
# step : 288 / 390.625
# top-1 percentage :  71.59%
# step : 289 / 390.625
# top-1 percentage :  71.60%
# step : 290 / 390.625
# top-1 percentage :  71.61%
# step : 291 / 390.625
# top-1 percentage :  71.61%
# step : 292 / 390.625
# top-1 percentage :  71.60%
# step : 293 / 390.625
# top-1 percentage :  71.61%
# step : 294 / 390.625
# top-1 percentage :  71.59%
# step : 295 / 390.625
# top-1 percentage :  71.58%
# step : 296 / 390.625
# top-1 percentage :  71.59%
# step : 297 / 390.625
# top-1 percentage :  71.58%
# step : 298 / 390.625
# top-1 percentage :  71.58%
# step : 299 / 390.625
# top-1 percentage :  71.59%
# step : 300 / 390.625
# top-1 percentage :  71.59%
# step : 301 / 390.625
# top-1 percentage :  71.60%
# step : 302 / 390.625
# top-1 percentage :  71.62%
# step : 303 / 390.625
# top-1 percentage :  71.63%
# step : 304 / 390.625
# top-1 percentage :  71.61%
# step : 305 / 390.625
# top-1 percentage :  71.63%
# step : 306 / 390.625
# top-1 percentage :  71.62%
# step : 307 / 390.625
# top-1 percentage :  71.63%
# step : 308 / 390.625
# top-1 percentage :  71.64%
# step : 309 / 390.625
# top-1 percentage :  71.63%
# step : 310 / 390.625
# top-1 percentage :  71.62%
# step : 311 / 390.625
# top-1 percentage :  71.61%
# step : 312 / 390.625
# top-1 percentage :  71.62%
# step : 313 / 390.625
# top-1 percentage :  71.63%
# step : 314 / 390.625
# top-1 percentage :  71.65%
# step : 315 / 390.625
# top-1 percentage :  71.64%
# step : 316 / 390.625
# top-1 percentage :  71.64%
# step : 317 / 390.625
# top-1 percentage :  71.64%
# step : 318 / 390.625
# top-1 percentage :  71.64%
# step : 319 / 390.625
# top-1 percentage :  71.64%
# step : 320 / 390.625
# top-1 percentage :  71.65%
# step : 321 / 390.625
# top-1 percentage :  71.66%
# step : 322 / 390.625
# top-1 percentage :  71.64%
# step : 323 / 390.625
# top-1 percentage :  71.63%
# step : 324 / 390.625
# top-1 percentage :  71.61%
# step : 325 / 390.625
# top-1 percentage :  71.62%
# step : 326 / 390.625
# top-1 percentage :  71.62%
# step : 327 / 390.625
# top-1 percentage :  71.63%
# step : 328 / 390.625
# top-1 percentage :  71.62%
# step : 329 / 390.625
# top-1 percentage :  71.62%
# step : 330 / 390.625
# top-1 percentage :  71.63%
# step : 331 / 390.625
# top-1 percentage :  71.64%
# step : 332 / 390.625
# top-1 percentage :  71.62%
# step : 333 / 390.625
# top-1 percentage :  71.62%
# step : 334 / 390.625
# top-1 percentage :  71.62%
# step : 335 / 390.625
# top-1 percentage :  71.62%
# step : 336 / 390.625
# top-1 percentage :  71.60%
# step : 337 / 390.625
# top-1 percentage :  71.60%
# step : 338 / 390.625
# top-1 percentage :  71.60%
# step : 339 / 390.625
# top-1 percentage :  71.62%
# step : 340 / 390.625
# top-1 percentage :  71.63%
# step : 341 / 390.625
# top-1 percentage :  71.63%
# step : 342 / 390.625
# top-1 percentage :  71.61%
# step : 343 / 390.625
# top-1 percentage :  71.62%
# step : 344 / 390.625
# top-1 percentage :  71.61%
# step : 345 / 390.625
# top-1 percentage :  71.61%
# step : 346 / 390.625
# top-1 percentage :  71.61%
# step : 347 / 390.625
# top-1 percentage :  71.62%
# step : 348 / 390.625
# top-1 percentage :  71.61%
# step : 349 / 390.625
# top-1 percentage :  71.62%
# step : 350 / 390.625
# top-1 percentage :  71.59%
# step : 351 / 390.625
# top-1 percentage :  71.57%
# step : 352 / 390.625
# top-1 percentage :  71.55%
# step : 353 / 390.625
# top-1 percentage :  71.55%
# step : 354 / 390.625
# top-1 percentage :  71.54%
# step : 355 / 390.625
# top-1 percentage :  71.54%
# step : 356 / 390.625
# top-1 percentage :  71.52%
# step : 357 / 390.625
# top-1 percentage :  71.52%
# step : 358 / 390.625
# top-1 percentage :  71.52%
# step : 359 / 390.625
# top-1 percentage :  71.54%
# step : 360 / 390.625
# top-1 percentage :  71.54%
# step : 361 / 390.625
# top-1 percentage :  71.54%
# step : 362 / 390.625
# top-1 percentage :  71.53%
# step : 363 / 390.625
# top-1 percentage :  71.53%
# step : 364 / 390.625
# top-1 percentage :  71.52%
# step : 365 / 390.625
# top-1 percentage :  71.50%
# step : 366 / 390.625
# top-1 percentage :  71.51%
# step : 367 / 390.625
# top-1 percentage :  71.51%
# step : 368 / 390.625
# top-1 percentage :  71.53%
# step : 369 / 390.625
# top-1 percentage :  71.52%
# step : 370 / 390.625
# top-1 percentage :  71.54%
# step : 371 / 390.625
# top-1 percentage :  71.55%
# step : 372 / 390.625
# top-1 percentage :  71.53%
# step : 373 / 390.625
# top-1 percentage :  71.52%
# step : 374 / 390.625
# top-1 percentage :  71.53%
# step : 375 / 390.625
# top-1 percentage :  71.54%
# step : 376 / 390.625
# top-1 percentage :  71.53%
# step : 377 / 390.625
# top-1 percentage :  71.53%
# step : 378 / 390.625
# top-1 percentage :  71.54%
# step : 379 / 390.625
# top-1 percentage :  71.55%
# step : 380 / 390.625
# top-1 percentage :  71.54%
# step : 381 / 390.625
# top-1 percentage :  71.54%
# step : 382 / 390.625
# top-1 percentage :  71.55%
# step : 383 / 390.625
# top-1 percentage :  71.55%
# step : 384 / 390.625
# top-1 percentage :  71.56%
# step : 385 / 390.625
# top-1 percentage :  71.58%
# step : 386 / 390.625
# top-1 percentage :  71.59%
# step : 387 / 390.625
# top-1 percentage :  71.59%
# step : 388 / 390.625
# top-1 percentage :  71.59%
# step : 389 / 390.625
# top-1 percentage :  71.60%
# step : 390 / 390.625
# top-1 percentage :  71.59%
# step : 391 / 625.0
# top-1 percentage :  71.59%
# ---------------------------------------------------------------
# top-1 percentage :  71.59%

# %%
from torchvision.models import googlenet
model = googlenet(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/googlenet-1378be20.pth" to /root/.cache/torch/hub/checkpoints/googlenet-1378be20.pth
# HBox(children=(FloatProgress(value=0.0, max=52147035.0), HTML(value='')))

# %%
import torch
import torchvision
import torch.utils.data as data
import torchvision.transforms as transforms


if __name__ == "__main__":
    device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
    normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std=[0.229, 0.224, 0.225])

    transform = transforms.Compose(
        [transforms.Resize(256),
         transforms.CenterCrop(224),
         transforms.ToTensor(),
         normalize,
         ])

    test_set = torchvision.datasets.ImageNet(root="./", transform=transform, split='val')
    test_loader = data.DataLoader(test_set, batch_size=128, shuffle=True, num_workers=2)

    model = torchvision.models.googlenet(pretrained=True).to(device)
    model.eval()

    correct_top1 = 0
    total = 0

    with torch.no_grad():
        for idx, (images, labels) in enumerate(test_loader):

            images = images.to(device)      # [100, 3, 224, 224]
            labels = labels.to(device)      # [100]
            outputs = model(images)

            # ------------------------------------------------------------------------------
            # rank 1
            _, pred = torch.max(outputs, 1)
            total += labels.size(0)
            correct_top1 += (pred == labels).sum().item()

            # ------------------------------------------------------------------------------

            print("step : {} / {}".format(idx + 1, len(test_set)/int(labels.size(0))))
            print("top-1 percentage :  {0:0.2f}%".format(correct_top1 / total * 100))
    print("---------------------------------------------------------------")         
    print("top-1 percentage :  {0:0.2f}%".format(correct_top1 / total * 100))
# Out:
# step : 1 / 390.625
# top-1 percentage :  75.00%
# step : 2 / 390.625
# top-1 percentage :  75.00%
# step : 3 / 390.625
# top-1 percentage :  73.18%
# step : 4 / 390.625
# top-1 percentage :  72.27%
# step : 5 / 390.625
# top-1 percentage :  72.81%
# step : 6 / 390.625
# top-1 percentage :  73.57%
# step : 7 / 390.625
# top-1 percentage :  72.77%
# step : 8 / 390.625
# top-1 percentage :  72.07%
# step : 9 / 390.625
# top-1 percentage :  70.66%
# step : 10 / 390.625
# top-1 percentage :  70.16%
# step : 11 / 390.625
# top-1 percentage :  69.39%
# step : 12 / 390.625
# top-1 percentage :  69.66%
# step : 13 / 390.625
# top-1 percentage :  69.77%
# step : 14 / 390.625
# top-1 percentage :  69.81%
# step : 15 / 390.625
# top-1 percentage :  69.74%
# step : 16 / 390.625
# top-1 percentage :  69.68%
# step : 17 / 390.625
# top-1 percentage :  69.94%
# step : 18 / 390.625
# top-1 percentage :  69.97%
# step : 19 / 390.625
# top-1 percentage :  69.70%
# step : 20 / 390.625
# top-1 percentage :  69.41%
# step : 21 / 390.625
# top-1 percentage :  69.75%
# step : 22 / 390.625
# top-1 percentage :  69.71%
# step : 23 / 390.625
# top-1 percentage :  69.60%
# step : 24 / 390.625
# top-1 percentage :  69.60%
# step : 25 / 390.625
# top-1 percentage :  69.69%
# step : 26 / 390.625
# top-1 percentage :  69.59%
# step : 27 / 390.625
# top-1 percentage :  69.68%
# step : 28 / 390.625
# top-1 percentage :  69.64%
# step : 29 / 390.625
# top-1 percentage :  69.83%
# step : 30 / 390.625
# top-1 percentage :  69.77%
# step : 31 / 390.625
# top-1 percentage :  69.56%
# step : 32 / 390.625
# top-1 percentage :  69.56%
# step : 33 / 390.625
# top-1 percentage :  69.74%
# step : 34 / 390.625
# top-1 percentage :  69.65%
# step : 35 / 390.625
# top-1 percentage :  69.71%
# step : 36 / 390.625
# top-1 percentage :  69.73%
# step : 37 / 390.625
# top-1 percentage :  69.76%
# step : 38 / 390.625
# top-1 percentage :  69.82%
# step : 39 / 390.625
# top-1 percentage :  69.61%
# step : 40 / 390.625
# top-1 percentage :  69.65%
# step : 41 / 390.625
# top-1 percentage :  69.59%
# step : 42 / 390.625
# top-1 percentage :  69.55%
# step : 43 / 390.625
# top-1 percentage :  69.44%
# step : 44 / 390.625
# top-1 percentage :  69.44%
# step : 45 / 390.625
# top-1 percentage :  69.41%
# step : 46 / 390.625
# top-1 percentage :  69.38%
# step : 47 / 390.625
# top-1 percentage :  69.25%
# step : 48 / 390.625
# top-1 percentage :  69.34%
# step : 49 / 390.625
# top-1 percentage :  69.37%
# step : 50 / 390.625
# top-1 percentage :  69.27%
# step : 51 / 390.625
# top-1 percentage :  69.35%
# step : 52 / 390.625
# top-1 percentage :  69.44%
# step : 53 / 390.625
# top-1 percentage :  69.46%
# step : 54 / 390.625
# top-1 percentage :  69.36%
# step : 55 / 390.625
# top-1 percentage :  69.42%
# step : 56 / 390.625
# top-1 percentage :  69.43%
# step : 57 / 390.625
# top-1 percentage :  69.42%
# step : 58 / 390.625
# top-1 percentage :  69.52%
# step : 59 / 390.625
# top-1 percentage :  69.52%
# step : 60 / 390.625
# top-1 percentage :  69.48%
# step : 61 / 390.625
# top-1 percentage :  69.44%
# step : 62 / 390.625
# top-1 percentage :  69.51%
# step : 63 / 390.625
# top-1 percentage :  69.51%
# step : 64 / 390.625
# top-1 percentage :  69.41%
# step : 65 / 390.625
# top-1 percentage :  69.47%
# step : 66 / 390.625
# top-1 percentage :  69.48%
# step : 67 / 390.625
# top-1 percentage :  69.58%
# step : 68 / 390.625
# top-1 percentage :  69.51%
# step : 69 / 390.625
# top-1 percentage :  69.47%
# step : 70 / 390.625
# top-1 percentage :  69.50%
# step : 71 / 390.625
# top-1 percentage :  69.52%
# step : 72 / 390.625
# top-1 percentage :  69.60%
# step : 73 / 390.625
# top-1 percentage :  69.61%
# step : 74 / 390.625
# top-1 percentage :  69.65%
# step : 75 / 390.625
# top-1 percentage :  69.69%
# step : 76 / 390.625
# top-1 percentage :  69.66%
# step : 77 / 390.625
# top-1 percentage :  69.71%
# step : 78 / 390.625
# top-1 percentage :  69.79%
# step : 79 / 390.625
# top-1 percentage :  69.75%
# step : 80 / 390.625
# top-1 percentage :  69.77%
# step : 81 / 390.625
# top-1 percentage :  69.79%
# step : 82 / 390.625
# top-1 percentage :  69.86%
# step : 83 / 390.625
# top-1 percentage :  69.95%
# step : 84 / 390.625
# top-1 percentage :  69.96%
# step : 85 / 390.625
# top-1 percentage :  69.97%
# step : 86 / 390.625
# top-1 percentage :  69.99%
# step : 87 / 390.625
# top-1 percentage :  69.92%
# step : 88 / 390.625
# top-1 percentage :  69.91%
# step : 89 / 390.625
# top-1 percentage :  69.94%
# step : 90 / 390.625
# top-1 percentage :  69.89%
# step : 91 / 390.625
# top-1 percentage :  69.93%
# step : 92 / 390.625
# top-1 percentage :  69.96%
# step : 93 / 390.625
# top-1 percentage :  70.02%
# step : 94 / 390.625
# top-1 percentage :  70.10%
# step : 95 / 390.625
# top-1 percentage :  70.07%
# step : 96 / 390.625
# top-1 percentage :  70.05%
# step : 97 / 390.625
# top-1 percentage :  70.09%
# step : 98 / 390.625
# top-1 percentage :  70.07%
# step : 99 / 390.625
# top-1 percentage :  70.05%
# step : 100 / 390.625
# top-1 percentage :  70.03%
# step : 101 / 390.625
# top-1 percentage :  70.05%
# step : 102 / 390.625
# top-1 percentage :  69.98%
# step : 103 / 390.625
# top-1 percentage :  70.02%
# step : 104 / 390.625
# top-1 percentage :  70.01%
# step : 105 / 390.625
# top-1 percentage :  69.98%
# step : 106 / 390.625
# top-1 percentage :  70.03%
# step : 107 / 390.625
# top-1 percentage :  70.02%
# step : 108 / 390.625
# top-1 percentage :  70.04%
# step : 109 / 390.625
# top-1 percentage :  70.00%
# step : 110 / 390.625
# top-1 percentage :  70.03%
# step : 111 / 390.625
# top-1 percentage :  70.06%
# step : 112 / 390.625
# top-1 percentage :  69.98%
# step : 113 / 390.625
# top-1 percentage :  69.93%
# step : 114 / 390.625
# top-1 percentage :  69.95%
# step : 115 / 390.625
# top-1 percentage :  69.93%
# step : 116 / 390.625
# top-1 percentage :  69.95%
# step : 117 / 390.625
# top-1 percentage :  69.95%
# step : 118 / 390.625
# top-1 percentage :  69.94%
# step : 119 / 390.625
# top-1 percentage :  69.93%
# step : 120 / 390.625
# top-1 percentage :  69.95%
# step : 121 / 390.625
# top-1 percentage :  69.90%
# step : 122 / 390.625
# top-1 percentage :  69.87%
# step : 123 / 390.625
# top-1 percentage :  69.80%
# step : 124 / 390.625
# top-1 percentage :  69.78%
# step : 125 / 390.625
# top-1 percentage :  69.76%
# step : 126 / 390.625
# top-1 percentage :  69.73%
# step : 127 / 390.625
# top-1 percentage :  69.72%
# step : 128 / 390.625
# top-1 percentage :  69.73%
# step : 129 / 390.625
# top-1 percentage :  69.68%
# step : 130 / 390.625
# top-1 percentage :  69.66%
# step : 131 / 390.625
# top-1 percentage :  69.66%
# step : 132 / 390.625
# top-1 percentage :  69.65%
# step : 133 / 390.625
# top-1 percentage :  69.65%
# step : 134 / 390.625
# top-1 percentage :  69.69%
# step : 135 / 390.625
# top-1 percentage :  69.62%
# step : 136 / 390.625
# top-1 percentage :  69.59%
# step : 137 / 390.625
# top-1 percentage :  69.58%
# step : 138 / 390.625
# top-1 percentage :  69.59%
# step : 139 / 390.625
# top-1 percentage :  69.62%
# step : 140 / 390.625
# top-1 percentage :  69.59%
# step : 141 / 390.625
# top-1 percentage :  69.62%
# step : 142 / 390.625
# top-1 percentage :  69.65%
# step : 143 / 390.625
# top-1 percentage :  69.66%
# step : 144 / 390.625
# top-1 percentage :  69.66%
# step : 145 / 390.625
# top-1 percentage :  69.69%
# step : 146 / 390.625
# top-1 percentage :  69.68%
# step : 147 / 390.625
# top-1 percentage :  69.70%
# step : 148 / 390.625
# top-1 percentage :  69.68%
# step : 149 / 390.625
# top-1 percentage :  69.68%
# step : 150 / 390.625
# top-1 percentage :  69.70%
# step : 151 / 390.625
# top-1 percentage :  69.69%
# step : 152 / 390.625
# top-1 percentage :  69.72%
# step : 153 / 390.625
# top-1 percentage :  69.76%
# step : 154 / 390.625
# top-1 percentage :  69.74%
# step : 155 / 390.625
# top-1 percentage :  69.74%
# step : 156 / 390.625
# top-1 percentage :  69.75%
# step : 157 / 390.625
# top-1 percentage :  69.76%
# step : 158 / 390.625
# top-1 percentage :  69.76%
# step : 159 / 390.625
# top-1 percentage :  69.76%
# step : 160 / 390.625
# top-1 percentage :  69.79%
# step : 161 / 390.625
# top-1 percentage :  69.81%
# step : 162 / 390.625
# top-1 percentage :  69.81%
# step : 163 / 390.625
# top-1 percentage :  69.80%
# step : 164 / 390.625
# top-1 percentage :  69.80%
# step : 165 / 390.625
# top-1 percentage :  69.80%
# step : 166 / 390.625
# top-1 percentage :  69.76%
# step : 167 / 390.625
# top-1 percentage :  69.76%
# step : 168 / 390.625
# top-1 percentage :  69.75%
# step : 169 / 390.625
# top-1 percentage :  69.73%
# step : 170 / 390.625
# top-1 percentage :  69.71%
# step : 171 / 390.625
# top-1 percentage :  69.73%
# step : 172 / 390.625
# top-1 percentage :  69.68%
# step : 173 / 390.625
# top-1 percentage :  69.68%
# step : 174 / 390.625
# top-1 percentage :  69.66%
# step : 175 / 390.625
# top-1 percentage :  69.67%
# step : 176 / 390.625
# top-1 percentage :  69.65%
# step : 177 / 390.625
# top-1 percentage :  69.68%
# step : 178 / 390.625
# top-1 percentage :  69.67%
# step : 179 / 390.625
# top-1 percentage :  69.68%
# step : 180 / 390.625
# top-1 percentage :  69.70%
# step : 181 / 390.625
# top-1 percentage :  69.68%
# step : 182 / 390.625
# top-1 percentage :  69.72%
# step : 183 / 390.625
# top-1 percentage :  69.72%
# step : 184 / 390.625
# top-1 percentage :  69.75%
# step : 185 / 390.625
# top-1 percentage :  69.78%
# step : 186 / 390.625
# top-1 percentage :  69.80%
# step : 187 / 390.625
# top-1 percentage :  69.79%
# step : 188 / 390.625
# top-1 percentage :  69.80%
# step : 189 / 390.625
# top-1 percentage :  69.76%
# step : 190 / 390.625
# top-1 percentage :  69.72%
# step : 191 / 390.625
# top-1 percentage :  69.72%
# step : 192 / 390.625
# top-1 percentage :  69.74%
# step : 193 / 390.625
# top-1 percentage :  69.73%
# step : 194 / 390.625
# top-1 percentage :  69.72%
# step : 195 / 390.625
# top-1 percentage :  69.74%
# step : 196 / 390.625
# top-1 percentage :  69.78%
# step : 197 / 390.625
# top-1 percentage :  69.78%
# step : 198 / 390.625
# top-1 percentage :  69.78%
# step : 199 / 390.625
# top-1 percentage :  69.79%
# step : 200 / 390.625
# top-1 percentage :  69.77%
# step : 201 / 390.625
# top-1 percentage :  69.74%
# step : 202 / 390.625
# top-1 percentage :  69.71%
# step : 203 / 390.625
# top-1 percentage :  69.69%
# step : 204 / 390.625
# top-1 percentage :  69.68%
# step : 205 / 390.625
# top-1 percentage :  69.67%
# step : 206 / 390.625
# top-1 percentage :  69.69%
# step : 207 / 390.625
# top-1 percentage :  69.66%
# step : 208 / 390.625
# top-1 percentage :  69.67%
# step : 209 / 390.625
# top-1 percentage :  69.66%
# step : 210 / 390.625
# top-1 percentage :  69.69%
# step : 211 / 390.625
# top-1 percentage :  69.68%
# step : 212 / 390.625
# top-1 percentage :  69.66%
# step : 213 / 390.625
# top-1 percentage :  69.68%
# step : 214 / 390.625
# top-1 percentage :  69.70%
# step : 215 / 390.625
# top-1 percentage :  69.71%
# step : 216 / 390.625
# top-1 percentage :  69.72%
# step : 217 / 390.625
# top-1 percentage :  69.72%
# step : 218 / 390.625
# top-1 percentage :  69.71%
# step : 219 / 390.625
# top-1 percentage :  69.73%
# step : 220 / 390.625
# top-1 percentage :  69.73%
# step : 221 / 390.625
# top-1 percentage :  69.75%
# step : 222 / 390.625
# top-1 percentage :  69.77%
# step : 223 / 390.625
# top-1 percentage :  69.80%
# step : 224 / 390.625
# top-1 percentage :  69.81%
# step : 225 / 390.625
# top-1 percentage :  69.78%
# step : 226 / 390.625
# top-1 percentage :  69.80%
# step : 227 / 390.625
# top-1 percentage :  69.78%
# step : 228 / 390.625
# top-1 percentage :  69.79%
# step : 229 / 390.625
# top-1 percentage :  69.80%
# step : 230 / 390.625
# top-1 percentage :  69.81%
# step : 231 / 390.625
# top-1 percentage :  69.81%
# step : 232 / 390.625
# top-1 percentage :  69.84%
# step : 233 / 390.625
# top-1 percentage :  69.82%
# step : 234 / 390.625
# top-1 percentage :  69.83%
# step : 235 / 390.625
# top-1 percentage :  69.79%
# step : 236 / 390.625
# top-1 percentage :  69.81%
# step : 237 / 390.625
# top-1 percentage :  69.82%
# step : 238 / 390.625
# top-1 percentage :  69.85%
# step : 239 / 390.625
# top-1 percentage :  69.85%
# step : 240 / 390.625
# top-1 percentage :  69.85%
# step : 241 / 390.625
# top-1 percentage :  69.86%
# step : 242 / 390.625
# top-1 percentage :  69.84%
# step : 243 / 390.625
# top-1 percentage :  69.85%
# step : 244 / 390.625
# top-1 percentage :  69.85%
# step : 245 / 390.625
# top-1 percentage :  69.88%
# step : 246 / 390.625
# top-1 percentage :  69.89%
# step : 247 / 390.625
# top-1 percentage :  69.87%
# step : 248 / 390.625
# top-1 percentage :  69.88%
# step : 249 / 390.625
# top-1 percentage :  69.87%
# step : 250 / 390.625
# top-1 percentage :  69.85%
# step : 251 / 390.625
# top-1 percentage :  69.86%
# step : 252 / 390.625
# top-1 percentage :  69.84%
# step : 253 / 390.625
# top-1 percentage :  69.86%
# step : 254 / 390.625
# top-1 percentage :  69.84%
# step : 255 / 390.625
# top-1 percentage :  69.86%
# step : 256 / 390.625
# top-1 percentage :  69.83%
# step : 257 / 390.625
# top-1 percentage :  69.83%
# step : 258 / 390.625
# top-1 percentage :  69.85%
# step : 259 / 390.625
# top-1 percentage :  69.83%
# step : 260 / 390.625
# top-1 percentage :  69.82%
# step : 261 / 390.625
# top-1 percentage :  69.81%
# step : 262 / 390.625
# top-1 percentage :  69.81%
# step : 263 / 390.625
# top-1 percentage :  69.81%
# step : 264 / 390.625
# top-1 percentage :  69.82%
# step : 265 / 390.625
# top-1 percentage :  69.83%
# step : 266 / 390.625
# top-1 percentage :  69.79%
# step : 267 / 390.625
# top-1 percentage :  69.76%
# step : 268 / 390.625
# top-1 percentage :  69.78%
# step : 269 / 390.625
# top-1 percentage :  69.75%
# step : 270 / 390.625
# top-1 percentage :  69.75%
# step : 271 / 390.625
# top-1 percentage :  69.75%
# step : 272 / 390.625
# top-1 percentage :  69.76%
# step : 273 / 390.625
# top-1 percentage :  69.75%
# step : 274 / 390.625
# top-1 percentage :  69.74%
# step : 275 / 390.625
# top-1 percentage :  69.75%
# step : 276 / 390.625
# top-1 percentage :  69.76%
# step : 277 / 390.625
# top-1 percentage :  69.77%
# step : 278 / 390.625
# top-1 percentage :  69.78%
# step : 279 / 390.625
# top-1 percentage :  69.75%
# step : 280 / 390.625
# top-1 percentage :  69.75%
# step : 281 / 390.625
# top-1 percentage :  69.76%
# step : 282 / 390.625
# top-1 percentage :  69.76%
# step : 283 / 390.625
# top-1 percentage :  69.77%
# step : 284 / 390.625
# top-1 percentage :  69.77%
# step : 285 / 390.625
# top-1 percentage :  69.79%
# step : 286 / 390.625
# top-1 percentage :  69.82%
# step : 287 / 390.625
# top-1 percentage :  69.83%
# step : 288 / 390.625
# top-1 percentage :  69.82%
# step : 289 / 390.625
# top-1 percentage :  69.83%
# step : 290 / 390.625
# top-1 percentage :  69.83%
# step : 291 / 390.625
# top-1 percentage :  69.85%
# step : 292 / 390.625
# top-1 percentage :  69.85%
# step : 293 / 390.625
# top-1 percentage :  69.84%
# step : 294 / 390.625
# top-1 percentage :  69.81%
# step : 295 / 390.625
# top-1 percentage :  69.81%
# step : 296 / 390.625
# top-1 percentage :  69.80%
# step : 297 / 390.625
# top-1 percentage :  69.81%
# step : 298 / 390.625
# top-1 percentage :  69.82%
# step : 299 / 390.625
# top-1 percentage :  69.82%
# step : 300 / 390.625
# top-1 percentage :  69.82%
# step : 301 / 390.625
# top-1 percentage :  69.85%
# step : 302 / 390.625
# top-1 percentage :  69.88%
# step : 303 / 390.625
# top-1 percentage :  69.87%
# step : 304 / 390.625
# top-1 percentage :  69.88%
# step : 305 / 390.625
# top-1 percentage :  69.88%
# step : 306 / 390.625
# top-1 percentage :  69.91%
# step : 307 / 390.625
# top-1 percentage :  69.91%
# step : 308 / 390.625
# top-1 percentage :  69.91%
# step : 309 / 390.625
# top-1 percentage :  69.90%
# step : 310 / 390.625
# top-1 percentage :  69.88%
# step : 311 / 390.625
# top-1 percentage :  69.87%
# step : 312 / 390.625
# top-1 percentage :  69.86%
# step : 313 / 390.625
# top-1 percentage :  69.84%
# step : 314 / 390.625
# top-1 percentage :  69.85%
# step : 315 / 390.625
# top-1 percentage :  69.87%
# step : 316 / 390.625
# top-1 percentage :  69.84%
# step : 317 / 390.625
# top-1 percentage :  69.84%
# step : 318 / 390.625
# top-1 percentage :  69.82%
# step : 319 / 390.625
# top-1 percentage :  69.83%
# step : 320 / 390.625
# top-1 percentage :  69.85%
# step : 321 / 390.625
# top-1 percentage :  69.83%
# step : 322 / 390.625
# top-1 percentage :  69.85%
# step : 323 / 390.625
# top-1 percentage :  69.86%
# step : 324 / 390.625
# top-1 percentage :  69.90%
# step : 325 / 390.625
# top-1 percentage :  69.90%
# step : 326 / 390.625
# top-1 percentage :  69.87%
# step : 327 / 390.625
# top-1 percentage :  69.87%
# step : 328 / 390.625
# top-1 percentage :  69.88%
# step : 329 / 390.625
# top-1 percentage :  69.89%
# step : 330 / 390.625
# top-1 percentage :  69.88%
# step : 331 / 390.625
# top-1 percentage :  69.87%
# step : 332 / 390.625
# top-1 percentage :  69.87%
# step : 333 / 390.625
# top-1 percentage :  69.86%
# step : 334 / 390.625
# top-1 percentage :  69.85%
# step : 335 / 390.625
# top-1 percentage :  69.84%
# step : 336 / 390.625
# top-1 percentage :  69.83%
# step : 337 / 390.625
# top-1 percentage :  69.81%
# step : 338 / 390.625
# top-1 percentage :  69.82%
# step : 339 / 390.625
# top-1 percentage :  69.82%
# step : 340 / 390.625
# top-1 percentage :  69.83%
# step : 341 / 390.625
# top-1 percentage :  69.83%
# step : 342 / 390.625
# top-1 percentage :  69.84%
# step : 343 / 390.625
# top-1 percentage :  69.84%
# step : 344 / 390.625
# top-1 percentage :  69.83%
# step : 345 / 390.625
# top-1 percentage :  69.84%
# step : 346 / 390.625
# top-1 percentage :  69.84%
# step : 347 / 390.625
# top-1 percentage :  69.83%
# step : 348 / 390.625
# top-1 percentage :  69.82%
# step : 349 / 390.625
# top-1 percentage :  69.83%
# step : 350 / 390.625
# top-1 percentage :  69.82%
# step : 351 / 390.625
# top-1 percentage :  69.83%
# step : 352 / 390.625
# top-1 percentage :  69.83%
# step : 353 / 390.625
# top-1 percentage :  69.84%
# step : 354 / 390.625
# top-1 percentage :  69.83%
# step : 355 / 390.625
# top-1 percentage :  69.83%
# step : 356 / 390.625
# top-1 percentage :  69.83%
# step : 357 / 390.625
# top-1 percentage :  69.84%
# step : 358 / 390.625
# top-1 percentage :  69.83%
# step : 359 / 390.625
# top-1 percentage :  69.81%
# step : 360 / 390.625
# top-1 percentage :  69.81%
# step : 361 / 390.625
# top-1 percentage :  69.82%
# step : 362 / 390.625
# top-1 percentage :  69.81%
# step : 363 / 390.625
# top-1 percentage :  69.81%
# step : 364 / 390.625
# top-1 percentage :  69.81%
# step : 365 / 390.625
# top-1 percentage :  69.80%
# step : 366 / 390.625
# top-1 percentage :  69.78%
# step : 367 / 390.625
# top-1 percentage :  69.81%
# step : 368 / 390.625
# top-1 percentage :  69.81%
# step : 369 / 390.625
# top-1 percentage :  69.80%
# step : 370 / 390.625
# top-1 percentage :  69.80%
# step : 371 / 390.625
# top-1 percentage :  69.81%
# step : 372 / 390.625
# top-1 percentage :  69.80%
# step : 373 / 390.625
# top-1 percentage :  69.81%
# step : 374 / 390.625
# top-1 percentage :  69.79%
# step : 375 / 390.625
# top-1 percentage :  69.79%
# step : 376 / 390.625
# top-1 percentage :  69.78%
# step : 377 / 390.625
# top-1 percentage :  69.78%
# step : 378 / 390.625
# top-1 percentage :  69.80%
# step : 379 / 390.625
# top-1 percentage :  69.79%
# step : 380 / 390.625
# top-1 percentage :  69.79%
# step : 381 / 390.625
# top-1 percentage :  69.81%
# step : 382 / 390.625
# top-1 percentage :  69.81%
# step : 383 / 390.625
# top-1 percentage :  69.79%
# step : 384 / 390.625
# top-1 percentage :  69.77%
# step : 385 / 390.625
# top-1 percentage :  69.77%
# step : 386 / 390.625
# top-1 percentage :  69.78%
# step : 387 / 390.625
# top-1 percentage :  69.77%
# step : 388 / 390.625
# top-1 percentage :  69.78%
# step : 389 / 390.625
# top-1 percentage :  69.77%
# step : 390 / 390.625
# top-1 percentage :  69.77%
# step : 391 / 625.0
# top-1 percentage :  69.78%
# ---------------------------------------------------------------
# top-1 percentage :  69.78%

# %%
from torchvision.models import resnet18
model = resnet18(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /root/.cache/torch/hub/checkpoints/resnet18-5c106cde.pth
# HBox(children=(FloatProgress(value=0.0, max=46827520.0), HTML(value='')))

# %%
import torch
import torchvision
import torch.utils.data as data
import torchvision.transforms as transforms


if __name__ == "__main__":
    device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
    normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std=[0.229, 0.224, 0.225])

    transform = transforms.Compose(
        [transforms.Resize(256),
         transforms.CenterCrop(224),
         transforms.ToTensor(),
         normalize,
         ])

    test_set = torchvision.datasets.ImageNet(root="./", transform=transform, split='val')
    test_loader = data.DataLoader(test_set, batch_size=128, shuffle=True, num_workers=2)

    model = torchvision.models.resnet18(pretrained=True).to(device)
    model.eval()

    correct_top1 = 0
    total = 0

    with torch.no_grad():
        for idx, (images, labels) in enumerate(test_loader):

            images = images.to(device)      # [100, 3, 224, 224]
            labels = labels.to(device)      # [100]
            outputs = model(images)

            # ------------------------------------------------------------------------------
            # rank 1
            _, pred = torch.max(outputs, 1)
            total += labels.size(0)
            correct_top1 += (pred == labels).sum().item()

            # ------------------------------------------------------------------------------

            print("step : {} / {}".format(idx + 1, len(test_set)/int(labels.size(0))))
            print("top-1 percentage :  {0:0.2f}%".format(correct_top1 / total * 100))
    print("---------------------------------------------------------------")         
    print("top-1 percentage :  {0:0.2f}%".format(correct_top1 / total * 100))
# Out:
# step : 1 / 390.625
# top-1 percentage :  74.22%
# step : 2 / 390.625
# top-1 percentage :  72.27%
# step : 3 / 390.625
# top-1 percentage :  70.05%
# step : 4 / 390.625
# top-1 percentage :  70.31%
# step : 5 / 390.625
# top-1 percentage :  71.56%
# step : 6 / 390.625
# top-1 percentage :  70.57%
# step : 7 / 390.625
# top-1 percentage :  71.43%
# step : 8 / 390.625
# top-1 percentage :  70.51%
# step : 9 / 390.625
# top-1 percentage :  70.23%
# step : 10 / 390.625
# top-1 percentage :  69.53%
# step : 11 / 390.625
# top-1 percentage :  69.89%
# step : 12 / 390.625
# top-1 percentage :  69.60%
# step : 13 / 390.625
# top-1 percentage :  69.89%
# step : 14 / 390.625
# top-1 percentage :  69.92%
# step : 15 / 390.625
# top-1 percentage :  70.10%
# step : 16 / 390.625
# top-1 percentage :  70.17%
# step : 17 / 390.625
# top-1 percentage :  70.17%
# step : 18 / 390.625
# top-1 percentage :  69.66%
# step : 19 / 390.625
# top-1 percentage :  69.61%
# step : 20 / 390.625
# top-1 percentage :  69.92%
# step : 21 / 390.625
# top-1 percentage :  69.94%
# step : 22 / 390.625
# top-1 percentage :  69.74%
# step : 23 / 390.625
# top-1 percentage :  70.11%
# step : 24 / 390.625
# top-1 percentage :  69.76%
# step : 25 / 390.625
# top-1 percentage :  69.75%
# step : 26 / 390.625
# top-1 percentage :  69.77%
# step : 27 / 390.625
# top-1 percentage :  69.79%
# step : 28 / 390.625
# top-1 percentage :  69.95%
# step : 29 / 390.625
# top-1 percentage :  69.75%
# step : 30 / 390.625
# top-1 percentage :  69.61%
# step : 31 / 390.625
# top-1 percentage :  69.56%
# step : 32 / 390.625
# top-1 percentage :  69.51%
# step : 33 / 390.625
# top-1 percentage :  69.53%
# step : 34 / 390.625
# top-1 percentage :  69.65%
# step : 35 / 390.625
# top-1 percentage :  69.71%
# step : 36 / 390.625
# top-1 percentage :  69.79%
# step : 37 / 390.625
# top-1 percentage :  69.85%
# step : 38 / 390.625
# top-1 percentage :  69.90%
# step : 39 / 390.625
# top-1 percentage :  69.79%
# step : 40 / 390.625
# top-1 percentage :  69.75%
# step : 41 / 390.625
# top-1 percentage :  70.01%
# step : 42 / 390.625
# top-1 percentage :  69.94%
# step : 43 / 390.625
# top-1 percentage :  69.97%
# step : 44 / 390.625
# top-1 percentage :  70.03%
# step : 45 / 390.625
# top-1 percentage :  70.12%
# step : 46 / 390.625
# top-1 percentage :  70.14%
# step : 47 / 390.625
# top-1 percentage :  70.08%
# step : 48 / 390.625
# top-1 percentage :  70.05%
# step : 49 / 390.625
# top-1 percentage :  70.03%
# step : 50 / 390.625
# top-1 percentage :  69.97%
# step : 51 / 390.625
# top-1 percentage :  69.82%
# step : 52 / 390.625
# top-1 percentage :  69.88%
# step : 53 / 390.625
# top-1 percentage :  70.00%
# step : 54 / 390.625
# top-1 percentage :  69.97%
# step : 55 / 390.625
# top-1 percentage :  69.84%
# step : 56 / 390.625
# top-1 percentage :  69.82%
# step : 57 / 390.625
# top-1 percentage :  69.82%
# step : 58 / 390.625
# top-1 percentage :  69.81%
# step : 59 / 390.625
# top-1 percentage :  69.74%
# step : 60 / 390.625
# top-1 percentage :  69.69%
# step : 61 / 390.625
# top-1 percentage :  69.80%
# step : 62 / 390.625
# top-1 percentage :  69.82%
# step : 63 / 390.625
# top-1 percentage :  69.97%
# step : 64 / 390.625
# top-1 percentage :  70.06%
# step : 65 / 390.625
# top-1 percentage :  69.99%
# step : 66 / 390.625
# top-1 percentage :  69.93%
# step : 67 / 390.625
# top-1 percentage :  69.88%
# step : 68 / 390.625
# top-1 percentage :  69.89%
# step : 69 / 390.625
# top-1 percentage :  69.85%
# step : 70 / 390.625
# top-1 percentage :  69.84%
# step : 71 / 390.625
# top-1 percentage :  69.75%
# step : 72 / 390.625
# top-1 percentage :  69.78%
# step : 73 / 390.625
# top-1 percentage :  69.85%
# step : 74 / 390.625
# top-1 percentage :  69.87%
# step : 75 / 390.625
# top-1 percentage :  69.94%
# step : 76 / 390.625
# top-1 percentage :  70.03%
# step : 77 / 390.625
# top-1 percentage :  70.03%
# step : 78 / 390.625
# top-1 percentage :  70.00%
# step : 79 / 390.625
# top-1 percentage :  70.09%
# step : 80 / 390.625
# top-1 percentage :  70.11%
# step : 81 / 390.625
# top-1 percentage :  70.21%
# step : 82 / 390.625
# top-1 percentage :  70.23%
# step : 83 / 390.625
# top-1 percentage :  70.24%
# step : 84 / 390.625
# top-1 percentage :  70.18%
# step : 85 / 390.625
# top-1 percentage :  70.12%
# step : 86 / 390.625
# top-1 percentage :  70.08%
# step : 87 / 390.625
# top-1 percentage :  70.11%
# step : 88 / 390.625
# top-1 percentage :  70.21%
# step : 89 / 390.625
# top-1 percentage :  70.20%
# step : 90 / 390.625
# top-1 percentage :  70.20%
# step : 91 / 390.625
# top-1 percentage :  70.17%
# step : 92 / 390.625
# top-1 percentage :  70.19%
# step : 93 / 390.625
# top-1 percentage :  70.14%
# step : 94 / 390.625
# top-1 percentage :  70.11%
# step : 95 / 390.625
# top-1 percentage :  70.09%
# step : 96 / 390.625
# top-1 percentage :  70.07%
# step : 97 / 390.625
# top-1 percentage :  70.06%
# step : 98 / 390.625
# top-1 percentage :  70.05%
# step : 99 / 390.625
# top-1 percentage :  70.04%
# step : 100 / 390.625
# top-1 percentage :  70.06%
# step : 101 / 390.625
# top-1 percentage :  70.10%
# step : 102 / 390.625
# top-1 percentage :  70.17%
# step : 103 / 390.625
# top-1 percentage :  70.14%
# step : 104 / 390.625
# top-1 percentage :  70.10%
# step : 105 / 390.625
# top-1 percentage :  70.10%
# step : 106 / 390.625
# top-1 percentage :  70.11%
# step : 107 / 390.625
# top-1 percentage :  70.08%
# step : 108 / 390.625
# top-1 percentage :  70.04%
# step : 109 / 390.625
# top-1 percentage :  69.98%
# step : 110 / 390.625
# top-1 percentage :  69.94%
# step : 111 / 390.625
# top-1 percentage :  69.93%
# step : 112 / 390.625
# top-1 percentage :  69.98%
# step : 113 / 390.625
# top-1 percentage :  70.02%
# step : 114 / 390.625
# top-1 percentage :  70.06%
# step : 115 / 390.625
# top-1 percentage :  70.07%
# step : 116 / 390.625
# top-1 percentage :  70.10%
# step : 117 / 390.625
# top-1 percentage :  70.10%
# step : 118 / 390.625
# top-1 percentage :  70.13%
# step : 119 / 390.625
# top-1 percentage :  70.10%
# step : 120 / 390.625
# top-1 percentage :  70.11%
# step : 121 / 390.625
# top-1 percentage :  70.15%
# step : 122 / 390.625
# top-1 percentage :  70.17%
# step : 123 / 390.625
# top-1 percentage :  70.11%
# step : 124 / 390.625
# top-1 percentage :  70.14%
# step : 125 / 390.625
# top-1 percentage :  70.08%
# step : 126 / 390.625
# top-1 percentage :  70.03%
# step : 127 / 390.625
# top-1 percentage :  70.04%
# step : 128 / 390.625
# top-1 percentage :  70.01%
# step : 129 / 390.625
# top-1 percentage :  69.99%
# step : 130 / 390.625
# top-1 percentage :  70.00%
# step : 131 / 390.625
# top-1 percentage :  69.96%
# step : 132 / 390.625
# top-1 percentage :  70.00%
# step : 133 / 390.625
# top-1 percentage :  70.02%
# step : 134 / 390.625
# top-1 percentage :  70.02%
# step : 135 / 390.625
# top-1 percentage :  69.99%
# step : 136 / 390.625
# top-1 percentage :  69.96%
# step : 137 / 390.625
# top-1 percentage :  69.98%
# step : 138 / 390.625
# top-1 percentage :  69.93%
# step : 139 / 390.625
# top-1 percentage :  69.99%
# step : 140 / 390.625
# top-1 percentage :  69.95%
# step : 141 / 390.625
# top-1 percentage :  69.89%
# step : 142 / 390.625
# top-1 percentage :  69.87%
# step : 143 / 390.625
# top-1 percentage :  69.85%
# step : 144 / 390.625
# top-1 percentage :  69.87%
# step : 145 / 390.625
# top-1 percentage :  69.92%
# step : 146 / 390.625
# top-1 percentage :  69.91%
# step : 147 / 390.625
# top-1 percentage :  69.92%
# step : 148 / 390.625
# top-1 percentage :  69.95%
# step : 149 / 390.625
# top-1 percentage :  70.00%
# step : 150 / 390.625
# top-1 percentage :  70.05%
# step : 151 / 390.625
# top-1 percentage :  70.09%
# step : 152 / 390.625
# top-1 percentage :  70.11%
# step : 153 / 390.625
# top-1 percentage :  70.09%
# step : 154 / 390.625
# top-1 percentage :  70.11%
# step : 155 / 390.625
# top-1 percentage :  70.09%
# step : 156 / 390.625
# top-1 percentage :  70.10%
# step : 157 / 390.625
# top-1 percentage :  70.06%
# step : 158 / 390.625
# top-1 percentage :  70.06%
# step : 159 / 390.625
# top-1 percentage :  70.00%
# step : 160 / 390.625
# top-1 percentage :  70.04%
# step : 161 / 390.625
# top-1 percentage :  70.01%
# step : 162 / 390.625
# top-1 percentage :  70.00%
# step : 163 / 390.625
# top-1 percentage :  70.02%
# step : 164 / 390.625
# top-1 percentage :  70.03%
# step : 165 / 390.625
# top-1 percentage :  70.03%
# step : 166 / 390.625
# top-1 percentage :  70.08%
# step : 167 / 390.625
# top-1 percentage :  70.05%
# step : 168 / 390.625
# top-1 percentage :  70.02%
# step : 169 / 390.625
# top-1 percentage :  70.04%
# step : 170 / 390.625
# top-1 percentage :  70.06%
# step : 171 / 390.625
# top-1 percentage :  70.07%
# step : 172 / 390.625
# top-1 percentage :  70.10%
# step : 173 / 390.625
# top-1 percentage :  70.09%
# step : 174 / 390.625
# top-1 percentage :  70.06%
# step : 175 / 390.625
# top-1 percentage :  70.09%
# step : 176 / 390.625
# top-1 percentage :  70.11%
# step : 177 / 390.625
# top-1 percentage :  70.07%
# step : 178 / 390.625
# top-1 percentage :  70.06%
# step : 179 / 390.625
# top-1 percentage :  70.06%
# step : 180 / 390.625
# top-1 percentage :  70.03%
# step : 181 / 390.625
# top-1 percentage :  70.03%
# step : 182 / 390.625
# top-1 percentage :  70.06%
# step : 183 / 390.625
# top-1 percentage :  70.07%
# step : 184 / 390.625
# top-1 percentage :  70.06%
# step : 185 / 390.625
# top-1 percentage :  70.05%
# step : 186 / 390.625
# top-1 percentage :  70.03%
# step : 187 / 390.625
# top-1 percentage :  70.03%
# step : 188 / 390.625
# top-1 percentage :  70.04%
# step : 189 / 390.625
# top-1 percentage :  70.09%
# step : 190 / 390.625
# top-1 percentage :  70.12%
# step : 191 / 390.625
# top-1 percentage :  70.12%
# step : 192 / 390.625
# top-1 percentage :  70.09%
# step : 193 / 390.625
# top-1 percentage :  70.11%
# step : 194 / 390.625
# top-1 percentage :  70.11%
# step : 195 / 390.625
# top-1 percentage :  70.14%
# step : 196 / 390.625
# top-1 percentage :  70.11%
# step : 197 / 390.625
# top-1 percentage :  70.13%
# step : 198 / 390.625
# top-1 percentage :  70.12%
# step : 199 / 390.625
# top-1 percentage :  70.14%
# step : 200 / 390.625
# top-1 percentage :  70.12%
# step : 201 / 390.625
# top-1 percentage :  70.11%
# step : 202 / 390.625
# top-1 percentage :  70.09%
# step : 203 / 390.625
# top-1 percentage :  70.09%
# step : 204 / 390.625
# top-1 percentage :  70.09%
# step : 205 / 390.625
# top-1 percentage :  70.09%
# step : 206 / 390.625
# top-1 percentage :  70.07%
# step : 207 / 390.625
# top-1 percentage :  70.06%
# step : 208 / 390.625
# top-1 percentage :  70.05%
# step : 209 / 390.625
# top-1 percentage :  70.07%
# step : 210 / 390.625
# top-1 percentage :  70.08%
# step : 211 / 390.625
# top-1 percentage :  70.07%
# step : 212 / 390.625
# top-1 percentage :  70.07%
# step : 213 / 390.625
# top-1 percentage :  70.08%
# step : 214 / 390.625
# top-1 percentage :  70.11%
# step : 215 / 390.625
# top-1 percentage :  70.09%
# step : 216 / 390.625
# top-1 percentage :  70.09%
# step : 217 / 390.625
# top-1 percentage :  70.05%
# step : 218 / 390.625
# top-1 percentage :  70.04%
# step : 219 / 390.625
# top-1 percentage :  70.02%
# step : 220 / 390.625
# top-1 percentage :  69.99%
# step : 221 / 390.625
# top-1 percentage :  70.02%
# step : 222 / 390.625
# top-1 percentage :  70.01%
# step : 223 / 390.625
# top-1 percentage :  70.01%
# step : 224 / 390.625
# top-1 percentage :  70.00%
# step : 225 / 390.625
# top-1 percentage :  69.99%
# step : 226 / 390.625
# top-1 percentage :  69.99%
# step : 227 / 390.625
# top-1 percentage :  69.97%
# step : 228 / 390.625
# top-1 percentage :  69.96%
# step : 229 / 390.625
# top-1 percentage :  69.93%
# step : 230 / 390.625
# top-1 percentage :  69.93%
# step : 231 / 390.625
# top-1 percentage :  69.94%
# step : 232 / 390.625
# top-1 percentage :  69.94%
# step : 233 / 390.625
# top-1 percentage :  69.94%
# step : 234 / 390.625
# top-1 percentage :  69.95%
# step : 235 / 390.625
# top-1 percentage :  69.94%
# step : 236 / 390.625
# top-1 percentage :  69.93%
# step : 237 / 390.625
# top-1 percentage :  69.93%
# step : 238 / 390.625
# top-1 percentage :  69.95%
# step : 239 / 390.625
# top-1 percentage :  69.95%
# step : 240 / 390.625
# top-1 percentage :  69.92%
# step : 241 / 390.625
# top-1 percentage :  69.91%
# step : 242 / 390.625
# top-1 percentage :  69.88%
# step : 243 / 390.625
# top-1 percentage :  69.89%
# step : 244 / 390.625
# top-1 percentage :  69.91%
# step : 245 / 390.625
# top-1 percentage :  69.92%
# step : 246 / 390.625
# top-1 percentage :  69.95%
# step : 247 / 390.625
# top-1 percentage :  69.96%
# step : 248 / 390.625
# top-1 percentage :  69.97%
# step : 249 / 390.625
# top-1 percentage :  69.97%
# step : 250 / 390.625
# top-1 percentage :  70.00%
# step : 251 / 390.625
# top-1 percentage :  70.00%
# step : 252 / 390.625
# top-1 percentage :  69.99%
# step : 253 / 390.625
# top-1 percentage :  69.98%
# step : 254 / 390.625
# top-1 percentage :  69.99%
# step : 255 / 390.625
# top-1 percentage :  70.02%
# step : 256 / 390.625
# top-1 percentage :  70.03%
# step : 257 / 390.625
# top-1 percentage :  70.03%
# step : 258 / 390.625
# top-1 percentage :  70.05%
# step : 259 / 390.625
# top-1 percentage :  70.03%
# step : 260 / 390.625
# top-1 percentage :  70.02%
# step : 261 / 390.625
# top-1 percentage :  70.04%
# step : 262 / 390.625
# top-1 percentage :  70.02%
# step : 263 / 390.625
# top-1 percentage :  70.02%
# step : 264 / 390.625
# top-1 percentage :  70.02%
# step : 265 / 390.625
# top-1 percentage :  70.01%
# step : 266 / 390.625
# top-1 percentage :  70.01%
# step : 267 / 390.625
# top-1 percentage :  70.02%
# step : 268 / 390.625
# top-1 percentage :  70.05%
# step : 269 / 390.625
# top-1 percentage :  70.05%
# step : 270 / 390.625
# top-1 percentage :  70.03%
# step : 271 / 390.625
# top-1 percentage :  70.01%
# step : 272 / 390.625
# top-1 percentage :  70.00%
# step : 273 / 390.625
# top-1 percentage :  69.99%
# step : 274 / 390.625
# top-1 percentage :  69.99%
# step : 275 / 390.625
# top-1 percentage :  69.99%
# step : 276 / 390.625
# top-1 percentage :  69.99%
# step : 277 / 390.625
# top-1 percentage :  70.02%
# step : 278 / 390.625
# top-1 percentage :  70.02%
# step : 279 / 390.625
# top-1 percentage :  70.05%
# step : 280 / 390.625
# top-1 percentage :  70.04%
# step : 281 / 390.625
# top-1 percentage :  70.04%
# step : 282 / 390.625
# top-1 percentage :  70.05%
# step : 283 / 390.625
# top-1 percentage :  70.05%
# step : 284 / 390.625
# top-1 percentage :  70.06%
# step : 285 / 390.625
# top-1 percentage :  70.05%
# step : 286 / 390.625
# top-1 percentage :  70.07%
# step : 287 / 390.625
# top-1 percentage :  70.08%
# step : 288 / 390.625
# top-1 percentage :  70.10%
# step : 289 / 390.625
# top-1 percentage :  70.10%
# step : 290 / 390.625
# top-1 percentage :  70.11%
# step : 291 / 390.625
# top-1 percentage :  70.09%
# step : 292 / 390.625
# top-1 percentage :  70.08%
# step : 293 / 390.625
# top-1 percentage :  70.09%
# step : 294 / 390.625
# top-1 percentage :  70.09%
# step : 295 / 390.625
# top-1 percentage :  70.09%
# step : 296 / 390.625
# top-1 percentage :  70.09%
# step : 297 / 390.625
# top-1 percentage :  70.07%
# step : 298 / 390.625
# top-1 percentage :  70.04%
# step : 299 / 390.625
# top-1 percentage :  70.03%
# step : 300 / 390.625
# top-1 percentage :  70.01%
# step : 301 / 390.625
# top-1 percentage :  69.98%
# step : 302 / 390.625
# top-1 percentage :  69.97%
# step : 303 / 390.625
# top-1 percentage :  69.97%
# step : 304 / 390.625
# top-1 percentage :  69.97%
# step : 305 / 390.625
# top-1 percentage :  69.96%
# step : 306 / 390.625
# top-1 percentage :  69.97%
# step : 307 / 390.625
# top-1 percentage :  69.93%
# step : 308 / 390.625
# top-1 percentage :  69.94%
# step : 309 / 390.625
# top-1 percentage :  69.92%
# step : 310 / 390.625
# top-1 percentage :  69.92%
# step : 311 / 390.625
# top-1 percentage :  69.92%
# step : 312 / 390.625
# top-1 percentage :  69.92%
# step : 313 / 390.625
# top-1 percentage :  69.90%
# step : 314 / 390.625
# top-1 percentage :  69.91%
# step : 315 / 390.625
# top-1 percentage :  69.92%
# step : 316 / 390.625
# top-1 percentage :  69.90%
# step : 317 / 390.625
# top-1 percentage :  69.91%
# step : 318 / 390.625
# top-1 percentage :  69.91%
# step : 319 / 390.625
# top-1 percentage :  69.92%
# step : 320 / 390.625
# top-1 percentage :  69.92%
# step : 321 / 390.625
# top-1 percentage :  69.89%
# step : 322 / 390.625
# top-1 percentage :  69.88%
# step : 323 / 390.625
# top-1 percentage :  69.87%
# step : 324 / 390.625
# top-1 percentage :  69.89%
# step : 325 / 390.625
# top-1 percentage :  69.89%
# step : 326 / 390.625
# top-1 percentage :  69.88%
# step : 327 / 390.625
# top-1 percentage :  69.88%
# step : 328 / 390.625
# top-1 percentage :  69.89%
# step : 329 / 390.625
# top-1 percentage :  69.90%
# step : 330 / 390.625
# top-1 percentage :  69.91%
# step : 331 / 390.625
# top-1 percentage :  69.89%
# step : 332 / 390.625
# top-1 percentage :  69.88%
# step : 333 / 390.625
# top-1 percentage :  69.88%
# step : 334 / 390.625
# top-1 percentage :  69.88%
# step : 335 / 390.625
# top-1 percentage :  69.87%
# step : 336 / 390.625
# top-1 percentage :  69.87%
# step : 337 / 390.625
# top-1 percentage :  69.87%
# step : 338 / 390.625
# top-1 percentage :  69.88%
# step : 339 / 390.625
# top-1 percentage :  69.88%
# step : 340 / 390.625
# top-1 percentage :  69.89%
# step : 341 / 390.625
# top-1 percentage :  69.88%
# step : 342 / 390.625
# top-1 percentage :  69.89%
# step : 343 / 390.625
# top-1 percentage :  69.90%
# step : 344 / 390.625
# top-1 percentage :  69.90%
# step : 345 / 390.625
# top-1 percentage :  69.91%
# step : 346 / 390.625
# top-1 percentage :  69.92%
# step : 347 / 390.625
# top-1 percentage :  69.92%
# step : 348 / 390.625
# top-1 percentage :  69.92%
# step : 349 / 390.625
# top-1 percentage :  69.92%
# step : 350 / 390.625
# top-1 percentage :  69.92%
# step : 351 / 390.625
# top-1 percentage :  69.93%
# step : 352 / 390.625
# top-1 percentage :  69.93%
# step : 353 / 390.625
# top-1 percentage :  69.93%
# step : 354 / 390.625
# top-1 percentage :  69.92%
# step : 355 / 390.625
# top-1 percentage :  69.91%
# step : 356 / 390.625
# top-1 percentage :  69.90%
# step : 357 / 390.625
# top-1 percentage :  69.89%
# step : 358 / 390.625
# top-1 percentage :  69.88%
# step : 359 / 390.625
# top-1 percentage :  69.88%
# step : 360 / 390.625
# top-1 percentage :  69.90%
# step : 361 / 390.625
# top-1 percentage :  69.89%
# step : 362 / 390.625
# top-1 percentage :  69.87%
# step : 363 / 390.625
# top-1 percentage :  69.85%
# step : 364 / 390.625
# top-1 percentage :  69.84%
# step : 365 / 390.625
# top-1 percentage :  69.86%
# step : 366 / 390.625
# top-1 percentage :  69.85%
# step : 367 / 390.625
# top-1 percentage :  69.83%
# step : 368 / 390.625
# top-1 percentage :  69.84%
# step : 369 / 390.625
# top-1 percentage :  69.86%
# step : 370 / 390.625
# top-1 percentage :  69.86%
# step : 371 / 390.625
# top-1 percentage :  69.85%
# step : 372 / 390.625
# top-1 percentage :  69.84%
# step : 373 / 390.625
# top-1 percentage :  69.83%
# step : 374 / 390.625
# top-1 percentage :  69.82%
# step : 375 / 390.625
# top-1 percentage :  69.81%
# step : 376 / 390.625
# top-1 percentage :  69.80%
# step : 377 / 390.625
# top-1 percentage :  69.78%
# step : 378 / 390.625
# top-1 percentage :  69.78%
# step : 379 / 390.625
# top-1 percentage :  69.78%
# step : 380 / 390.625
# top-1 percentage :  69.76%
# step : 381 / 390.625
# top-1 percentage :  69.76%
# step : 382 / 390.625
# top-1 percentage :  69.76%
# step : 383 / 390.625
# top-1 percentage :  69.76%
# step : 384 / 390.625
# top-1 percentage :  69.76%
# step : 385 / 390.625
# top-1 percentage :  69.75%
# step : 386 / 390.625
# top-1 percentage :  69.75%
# step : 387 / 390.625
# top-1 percentage :  69.76%
# step : 388 / 390.625
# top-1 percentage :  69.75%
# step : 389 / 390.625
# top-1 percentage :  69.75%
# step : 390 / 390.625
# top-1 percentage :  69.75%
# step : 391 / 625.0
# top-1 percentage :  69.76%
# ---------------------------------------------------------------
# top-1 percentage :  69.76%
